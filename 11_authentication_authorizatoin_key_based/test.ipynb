# %%
import requests

res = requests.post(
    "http://localhost:8000/invoke",
    json={
        "tool": "add",
        "args": {"a": 10, "b": 20},
        "callback_url": "http://localhost:9000/callback"
    },
    headers={"x-api-key": "controller-key"}
)

# %%
print(res.json())
# Out:
# {'status': 'accepted'}
